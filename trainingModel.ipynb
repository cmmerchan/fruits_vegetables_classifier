# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential, Model

# %%
TRAIN_PATH = '../input/fruits-fresh-and-rotten-for-classification/dataset/train/'
TEST_PATH = '../input/fruits-fresh-and-rotten-for-classification/dataset/test/'
SIZE = (240, 240)

# %%
labels = []
for class_ in os.listdir(TRAIN_PATH):
    labels.append(class_)
NUM_LABELS = len(labels)

print(labels)
# Out:
# ['rottenbanana', 'freshoranges', 'rottenoranges', 'freshbanana', 'rottenapples', 'freshapples']

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen=ImageDataGenerator(rescale=1./255, validation_split = 0.1)
test_datagen = ImageDataGenerator(rescale=1./255) 

'''
Comments:
- ImageDataGenerator will resize all images to target_size
- x_col is the column where the images' names are
- y_col is the column where the labels are
- has_ext means that the images' names include a file extension, e.g. image_name.jpg
- Here you can change the targe_size to resize all images to different shapes.
Maybe larger images help in getting a better accuracy
'''
train_dataset = datagen.flow_from_directory(batch_size=32,
                                                 directory=TRAIN_PATH,
                                                 shuffle=True,
                                                classes=labels,
                                                 target_size=SIZE, 
                                                 subset="training",
                                                 class_mode='categorical')

val_dataset = datagen.flow_from_directory(batch_size=32,
                                                 directory=TRAIN_PATH,
                                                 shuffle=True,
                                                classes=labels,
                                                 target_size=SIZE, 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 9813 images belonging to 6 classes.
# Found 1088 images belonging to 6 classes.

# %%
fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(15, 12))
idx = 0

for i in range(3):
    for j in range(4):
        label = labels[np.argmax(train_dataset[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_dataset[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

# plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu', input_shape = (240,240,3)))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D((2,2)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(64, activation='relu'))

model.add(tf.keras.layers.Dense(6, activation='softmax'))
model.compile(optimizer='adam', loss = 'categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2022-12-13 04:55:40.703609: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 238, 238, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 119, 119, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 119, 119, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 117, 117, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 58, 58, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 58, 58, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               12845184
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 12,947,078
# Trainable params: 12,947,078
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(generator=train_dataset, steps_per_epoch=len(train_dataset), epochs=12, validation_data=val_dataset, validation_steps=len(val_dataset))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-12-13 04:55:41.077122: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/12
# 307/307 [==============================] - 492s 2s/step - loss: 0.9819 - accuracy: 0.6434 - val_loss: 0.4597 - val_accuracy: 0.8244
# Epoch 2/12
# 307/307 [==============================] - 498s 2s/step - loss: 0.3209 - accuracy: 0.8856 - val_loss: 0.3312 - val_accuracy: 0.8805
# Epoch 3/12
# 307/307 [==============================] - 491s 2s/step - loss: 0.2077 - accuracy: 0.9229 - val_loss: 0.1574 - val_accuracy: 0.9504
# Epoch 4/12
# 307/307 [==============================] - 503s 2s/step - loss: 0.1647 - accuracy: 0.9403 - val_loss: 0.1345 - val_accuracy: 0.9531
# Epoch 5/12
# 307/307 [==============================] - 495s 2s/step - loss: 0.1207 - accuracy: 0.9571 - val_loss: 0.1242 - val_accuracy: 0.9568
# Epoch 6/12
# 307/307 [==============================] - 490s 2s/step - loss: 0.1089 - accuracy: 0.9616 - val_loss: 0.0888 - val_accuracy: 0.9761
# Epoch 7/12
# 307/307 [==============================] - 485s 2s/step - loss: 0.0919 - accuracy: 0.9675 - val_loss: 0.1529 - val_accuracy: 0.9540
# Epoch 8/12
# 307/307 [==============================] - 496s 2s/step - loss: 0.0631 - accuracy: 0.9780 - val_loss: 0.0996 - val_accuracy: 0.9669
# Epoch 9/12
# 307/307 [==============================] - 501s 2s/step - loss: 0.0728 - accuracy: 0.9746 - val_loss: 0.2300 - val_accuracy: 0.9320
# Epoch 10/12
# 307/307 [==============================] - 493s 2s/step - loss: 0.0649 - accuracy: 0.9779 - val_loss: 0.0439 - val_accuracy: 0.9871
# Epoch 11/12
# 307/307 [==============================] - 493s 2s/step - loss: 0.0493 - accuracy: 0.9818 - val_loss: 0.0359 - val_accuracy: 0.9890
# Epoch 12/12
# 307/307 [==============================] - 495s 2s/step - loss: 0.0601 - accuracy: 0.9802 - val_loss: 0.0581 - val_accuracy: 0.9789

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Acc','Val'], loc = 'lower right')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['loss','Val'], loc = 'upper right')

# %%
# learning_rate = history.history['lr']
# plt.plot(history.history['lr'])
# plt.title('Learning Rate')
# plt.xlabel('Epochs')
# plt.ylabel('Learning Rate')
# plt.legend(['loss','Val'], loc = 'upper right')

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(TEST_PATH,
                                                  batch_size=1,
                                                  target_size=SIZE,
                                                  shuffle = False,
                                                  classes=labels,
                                                  class_mode='categorical')


filenames = test_generator.filenames
nb_samples = len(filenames)

loss, acc = model.evaluate(test_generator,steps = (nb_samples), verbose=1)
print('accuracy test: ',acc)
print('loss test: ',loss)
# Out:
# Found 2698 images belonging to 6 classes.
# 2698/2698 [==============================] - 64s 24ms/step - loss: 0.1103 - accuracy: 0.9607
# accuracy test:  0.960711658000946
# loss test:  0.11030465364456177

# %%
predictions = model.predict(test_generator)
files=test_generator.filenames
class_dict=test_generator.class_indices # a dictionary of the form class name: class index
rev_dict={}
for key, value in class_dict.items():
    rev_dict[value]=key

for i, p in enumerate(predictions):
    index=np.argmax(p)
    klass=rev_dict[index]    
    prob=p[index]
    print('for file ', files[i], ' predicted class is ', klass,' with probability ',prob)
# Out:
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.47.41 PM.png  predicted class is  rottenbanana  with probability  0.9999889
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.47.51 PM.png  predicted class is  rottenbanana  with probability  0.99998045
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.48.40 PM.png  predicted class is  rottenbanana  with probability  0.9999695
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.49.25 PM.png  predicted class is  rottenbanana  with probability  0.9994955
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.49.41 PM.png  predicted class is  rottenbanana  with probability  0.9987293
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.51.00 PM.png  predicted class is  rottenbanana  with probability  0.9999809
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.51.46 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.52.16 PM.png  predicted class is  rottenbanana  with probability  0.9999895
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.52.21 PM.png  predicted class is  rottenbanana  with probability  0.99997866
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.53.09 PM.png  predicted class is  rottenbanana  with probability  0.99999917
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.53.47 PM.png  predicted class is  rottenbanana  with probability  0.9995278
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.54.00 PM.png  predicted class is  rottenbanana  with probability  0.99998
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.54.07 PM.png  predicted class is  rottenbanana  with probability  0.9999943
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.54.23 PM.png  predicted class is  rottenbanana  with probability  0.99999976
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.54.48 PM.png  predicted class is  rottenbanana  with probability  0.99994946
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.56.01 PM.png  predicted class is  rottenbanana  with probability  0.99999213
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.57.14 PM.png  predicted class is  rottenbanana  with probability  0.9999938
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.57.54 PM.png  predicted class is  rottenbanana  with probability  0.99998033
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.58.38 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.58.43 PM.png  predicted class is  rottenbanana  with probability  0.9999522
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.58.57 PM.png  predicted class is  rottenbanana  with probability  0.99999416
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.59.02 PM.png  predicted class is  rottenbanana  with probability  0.999959
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.59.15 PM.png  predicted class is  rottenbanana  with probability  0.9996997
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.59.23 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.59.44 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/Screen Shot 2018-06-12 at 8.59.51 PM.png  predicted class is  rottenbanana  with probability  0.9999964
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.00.22 PM.png  predicted class is  rottenbanana  with probability  0.9999993
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.01.10 PM.png  predicted class is  rottenbanana  with probability  0.9999869
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.01.26 PM.png  predicted class is  rottenbanana  with probability  0.9999994
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.03.34 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.04.15 PM.png  predicted class is  rottenbanana  with probability  0.99999654
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.04.41 PM.png  predicted class is  rottenbanana  with probability  0.99986494
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.04.47 PM.png  predicted class is  rottenbanana  with probability  0.99999344
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.05.37 PM.png  predicted class is  rottenbanana  with probability  0.9999516
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.06.33 PM.png  predicted class is  rottenbanana  with probability  0.9997898
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.07.46 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.09.05 PM.png  predicted class is  rottenbanana  with probability  0.9999639
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.09.29 PM.png  predicted class is  rottenbanana  with probability  0.99999106
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.09.55 PM.png  predicted class is  rottenbanana  with probability  0.9999933
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.10.20 PM.png  predicted class is  rottenbanana  with probability  0.9995473
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.11.00 PM.png  predicted class is  rottenbanana  with probability  0.99996173
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.11.35 PM.png  predicted class is  rottenbanana  with probability  0.9885803
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.12.40 PM.png  predicted class is  rottenbanana  with probability  0.99999547
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.12.45 PM.png  predicted class is  rottenbanana  with probability  0.9999622
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.12.57 PM.png  predicted class is  rottenbanana  with probability  0.99988353
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.13.16 PM.png  predicted class is  rottenbanana  with probability  0.99873763
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.13.21 PM.png  predicted class is  rottenbanana  with probability  0.9993038
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.13.34 PM.png  predicted class is  rottenbanana  with probability  0.99999416
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.13.44 PM.png  predicted class is  rottenbanana  with probability  0.9999902
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.13.48 PM.png  predicted class is  rottenbanana  with probability  0.9998159
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.14.07 PM.png  predicted class is  rottenbanana  with probability  0.9999956
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.14.22 PM.png  predicted class is  rottenbanana  with probability  0.9999646
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.16.20 PM.png  predicted class is  rottenbanana  with probability  0.9999348
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.16.28 PM.png  predicted class is  rottenbanana  with probability  0.99999166
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.16.57 PM.png  predicted class is  rottenbanana  with probability  0.9988102
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.17.57 PM.png  predicted class is  rottenbanana  with probability  0.9999734
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.18.57 PM.png  predicted class is  rottenbanana  with probability  0.99986506
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.19.17 PM.png  predicted class is  rottenbanana  with probability  0.99988186
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.21.25 PM.png  predicted class is  rottenbanana  with probability  0.99970263
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.22.32 PM.png  predicted class is  rottenbanana  with probability  0.9999975
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.25.00 PM.png  predicted class is  rottenbanana  with probability  0.99989176
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.25.23 PM.png  predicted class is  rottenbanana  with probability  0.9999882
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.25.28 PM.png  predicted class is  rottenbanana  with probability  0.9991793
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.25.41 PM.png  predicted class is  rottenbanana  with probability  0.99999714
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.27.26 PM.png  predicted class is  rottenbanana  with probability  0.999997
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.27.35 PM.png  predicted class is  rottenbanana  with probability  0.999995
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.27.56 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/Screen Shot 2018-06-12 at 9.28.04 PM.png  predicted class is  rottenbanana  with probability  0.9999714
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.47.51 PM.png  predicted class is  rottenbanana  with probability  0.99999905
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.48.18 PM.png  predicted class is  rottenbanana  with probability  0.99999344
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.49.59 PM.png  predicted class is  rottenbanana  with probability  0.9998958
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.51.00 PM.png  predicted class is  rottenbanana  with probability  0.9999901
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.51.46 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.52.48 PM.png  predicted class is  rottenbanana  with probability  0.99999166
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.53.29 PM.png  predicted class is  rottenbanana  with probability  0.9999939
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.53.54 PM.png  predicted class is  rottenbanana  with probability  0.99994135
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.54.14 PM.png  predicted class is  rottenbanana  with probability  0.98725045
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.54.23 PM.png  predicted class is  rottenbanana  with probability  0.99999976
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.56.16 PM.png  predicted class is  rottenbanana  with probability  0.99999964
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.56.37 PM.png  predicted class is  rottenbanana  with probability  0.9999089
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.56.54 PM.png  predicted class is  rottenbanana  with probability  0.9999833
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.56.59 PM.png  predicted class is  rottenbanana  with probability  0.9999341
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.57.04 PM.png  predicted class is  rottenbanana  with probability  0.9999957
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.58.13 PM.png  predicted class is  rottenbanana  with probability  0.99999905
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.59.15 PM.png  predicted class is  rottenbanana  with probability  0.99971086
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.59.23 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.59.32 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.59.51 PM.png  predicted class is  rottenbanana  with probability  0.99995005
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.00.22 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.00.49 PM.png  predicted class is  rottenbanana  with probability  0.99998546
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.01.21 PM.png  predicted class is  rottenbanana  with probability  0.99998665
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.01.56 PM.png  predicted class is  rottenbanana  with probability  0.9999951
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.02.44 PM.png  predicted class is  rottenbanana  with probability  0.9999993
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.03.46 PM.png  predicted class is  rottenbanana  with probability  0.9999944
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.04.41 PM.png  predicted class is  rottenbanana  with probability  0.9999701
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.05.02 PM.png  predicted class is  rottenbanana  with probability  0.99999976
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.06.13 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.07.35 PM.png  predicted class is  rottenbanana  with probability  0.99999905
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.09.05 PM.png  predicted class is  rottenbanana  with probability  0.9999969
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.09.43 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.09.55 PM.png  predicted class is  rottenbanana  with probability  0.9998016
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.10.04 PM.png  predicted class is  rottenbanana  with probability  0.99999964
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.10.37 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.10.55 PM.png  predicted class is  rottenbanana  with probability  0.99987805
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.11.35 PM.png  predicted class is  rottenbanana  with probability  0.9821145
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.11.47 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.12.32 PM.png  predicted class is  rottenbanana  with probability  0.9889337
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.12.45 PM.png  predicted class is  rottenbanana  with probability  0.99998283
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.12.57 PM.png  predicted class is  rottenbanana  with probability  0.9999188
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.13.39 PM.png  predicted class is  rottenbanana  with probability  0.9999788
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.16.20 PM.png  predicted class is  rottenbanana  with probability  0.9999949
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.18.43 PM.png  predicted class is  rottenbanana  with probability  0.9999279
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.18.50 PM.png  predicted class is  rottenbanana  with probability  0.9972078
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.19.35 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.20.07 PM.png  predicted class is  rottenbanana  with probability  0.9706956
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.20.14 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.20.36 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.21.05 PM.png  predicted class is  rottenbanana  with probability  0.9995888
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.22.19 PM.png  predicted class is  rottenbanana  with probability  0.9999957
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.22.50 PM.png  predicted class is  rottenbanana  with probability  0.9994123
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.26.27 PM.png  predicted class is  rottenbanana  with probability  0.99999964
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.27.11 PM.png  predicted class is  rottenbanana  with probability  0.9999994
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.27.35 PM.png  predicted class is  rottenbanana  with probability  0.99999416
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.27.41 PM.png  predicted class is  rottenbanana  with probability  0.99999416
# for file  rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.27.46 PM.png  predicted class is  rottenbanana  with probability  0.9999943
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.49.20 PM.png  predicted class is  rottenbanana  with probability  0.9999956
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.49.59 PM.png  predicted class is  rottenbanana  with probability  0.99995387
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.00 PM.png  predicted class is  rottenbanana  with probability  0.9990409
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.07 PM.png  predicted class is  rottenbanana  with probability  0.9999809
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.23 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.30 PM.png  predicted class is  rottenbanana  with probability  0.9999534
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.37 PM.png  predicted class is  rottenbanana  with probability  0.99987006
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.43 PM.png  predicted class is  rottenbanana  with probability  0.9995932
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.55.15 PM.png  predicted class is  rottenbanana  with probability  0.9999733
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.56.11 PM.png  predicted class is  rottenbanana  with probability  0.99999833
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.56.41 PM.png  predicted class is  rottenbanana  with probability  0.99993396
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.57.22 PM.png  predicted class is  rottenbanana  with probability  0.99878937
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.57.29 PM.png  predicted class is  rottenbanana  with probability  0.99987066
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.58.13 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.58.18 PM.png  predicted class is  rottenbanana  with probability  0.9999627
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.59.23 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.00.31 PM.png  predicted class is  rottenbanana  with probability  0.99999857
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.00.49 PM.png  predicted class is  rottenbanana  with probability  0.9999889
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.01.10 PM.png  predicted class is  rottenbanana  with probability  0.999869
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.02.52 PM.png  predicted class is  rottenbanana  with probability  0.9998216
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.03.25 PM.png  predicted class is  rottenbanana  with probability  0.99996686
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.03.46 PM.png  predicted class is  rottenbanana  with probability  0.9999813
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.04.15 PM.png  predicted class is  rottenbanana  with probability  0.99997497
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.04.19 PM.png  predicted class is  rottenbanana  with probability  0.9999988
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.07.08 PM.png  predicted class is  rottenbanana  with probability  0.9999918
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.07.46 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.08.00 PM.png  predicted class is  rottenbanana  with probability  0.9999968
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.08.12 PM.png  predicted class is  rottenbanana  with probability  0.9999993
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.08.26 PM.png  predicted class is  rottenbanana  with probability  0.99999905
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.08.43 PM.png  predicted class is  rottenbanana  with probability  0.9999964
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.10.37 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.10.45 PM.png  predicted class is  rottenbanana  with probability  0.99868363
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.11.05 PM.png  predicted class is  rottenbanana  with probability  0.9999932
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.11.17 PM.png  predicted class is  rottenbanana  with probability  0.9999994
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.11.27 PM.png  predicted class is  rottenbanana  with probability  0.9999738
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.11.58 PM.png  predicted class is  rottenbanana  with probability  0.9999931
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.12.17 PM.png  predicted class is  rottenbanana  with probability  0.9999865
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.13.10 PM.png  predicted class is  rottenbanana  with probability  0.99999964
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.14.48 PM.png  predicted class is  rottenbanana  with probability  0.99995327
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.16.34 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.16.47 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.16.53 PM.png  predicted class is  rottenbanana  with probability  0.9999881
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.16.57 PM.png  predicted class is  rottenbanana  with probability  0.99925715
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.18.11 PM.png  predicted class is  rottenbanana  with probability  0.9998005
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.18.50 PM.png  predicted class is  rottenbanana  with probability  0.9784883
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.19.08 PM.png  predicted class is  rottenbanana  with probability  0.9999808
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.19.35 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.19.42 PM.png  predicted class is  rottenbanana  with probability  0.999212
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.19.49 PM.png  predicted class is  rottenbanana  with probability  0.99991226
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.20.36 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.22.32 PM.png  predicted class is  rottenbanana  with probability  0.9999907
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.25.09 PM.png  predicted class is  rottenbanana  with probability  0.9999989
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.25.41 PM.png  predicted class is  rottenbanana  with probability  0.9999871
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.26.01 PM.png  predicted class is  rottenbanana  with probability  0.99999857
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.26.13 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.27.15 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.27.31 PM.png  predicted class is  rottenbanana  with probability  0.999997
# for file  rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.27.56 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.47.28 PM.png  predicted class is  rottenbanana  with probability  0.9999393
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.47.51 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.49.20 PM.png  predicted class is  rottenbanana  with probability  0.99996305
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.49.59 PM.png  predicted class is  rottenbanana  with probability  0.99957556
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.53.09 PM.png  predicted class is  rottenbanana  with probability  0.99997103
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.54.14 PM.png  predicted class is  rottenbanana  with probability  0.99703896
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.54.30 PM.png  predicted class is  rottenbanana  with probability  0.9999932
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.54.58 PM.png  predicted class is  rottenbanana  with probability  0.99999976
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.56.30 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.56.54 PM.png  predicted class is  rottenbanana  with probability  0.9998925
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.57.22 PM.png  predicted class is  rottenbanana  with probability  0.9810116
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.57.34 PM.png  predicted class is  rottenbanana  with probability  0.9999548
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.58.13 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.58.38 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.59.57 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.00.22 PM.png  predicted class is  rottenbanana  with probability  0.9999949
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.01.27 PM.png  predicted class is  rottenbanana  with probability  0.9949904
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.01.32 PM.png  predicted class is  rottenbanana  with probability  0.9978123
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.01.51 PM.png  predicted class is  rottenbanana  with probability  0.99999774
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.02.15 PM.png  predicted class is  rottenbanana  with probability  0.9999902
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.02.32 PM.png  predicted class is  rottenbanana  with probability  0.9999981
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.03.01 PM.png  predicted class is  rottenbanana  with probability  0.9992106
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.03.12 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.03.21 PM.png  predicted class is  rottenbanana  with probability  0.9999963
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.03.46 PM.png  predicted class is  rottenbanana  with probability  0.9999881
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.04.41 PM.png  predicted class is  rottenbanana  with probability  0.99999106
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.05.32 PM.png  predicted class is  rottenbanana  with probability  0.9999931
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.05.37 PM.png  predicted class is  rottenbanana  with probability  0.9999974
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.06.33 PM.png  predicted class is  rottenbanana  with probability  0.999992
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.07.35 PM.png  predicted class is  rottenbanana  with probability  0.99999976
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.09.09 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.10.37 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.13.39 PM.png  predicted class is  rottenbanana  with probability  0.999877
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.13.48 PM.png  predicted class is  rottenbanana  with probability  0.9999939
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.14.28 PM.png  predicted class is  rottenbanana  with probability  0.99999905
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.16.20 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.16.57 PM.png  predicted class is  rottenbanana  with probability  0.9999777
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.17.44 PM.png  predicted class is  rottenbanana  with probability  0.9999604
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.18.43 PM.png  predicted class is  rottenbanana  with probability  0.9962379
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.20.07 PM.png  predicted class is  rottenbanana  with probability  0.98524874
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.20.14 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.20.56 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.22.37 PM.png  predicted class is  rottenbanana  with probability  0.9999658
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.22.57 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.23.24 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.25.23 PM.png  predicted class is  rottenbanana  with probability  0.999943
# for file  rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.25.54 PM.png  predicted class is  rottenbanana  with probability  0.99999535
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.47.28 PM.png  predicted class is  rottenbanana  with probability  0.9999639
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.49.04 PM.png  predicted class is  rottenbanana  with probability  0.9997285
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.49.30 PM.png  predicted class is  rottenbanana  with probability  0.9911209
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.50.40 PM.png  predicted class is  rottenbanana  with probability  0.99998593
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.51.38 PM.png  predicted class is  rottenbanana  with probability  0.99995756
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.51.46 PM.png  predicted class is  rottenbanana  with probability  0.9999269
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.52.37 PM.png  predicted class is  rottenbanana  with probability  0.9999987
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.53.29 PM.png  predicted class is  rottenbanana  with probability  0.9999858
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.53.54 PM.png  predicted class is  rottenbanana  with probability  0.99966025
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.54.30 PM.png  predicted class is  rottenbanana  with probability  0.99999607
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.55.08 PM.png  predicted class is  rottenbanana  with probability  0.9999529
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.56.01 PM.png  predicted class is  rottenbanana  with probability  0.99993205
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.56.21 PM.png  predicted class is  rottenbanana  with probability  0.99998796
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.56.30 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.56.54 PM.png  predicted class is  rottenbanana  with probability  0.9999018
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.57.22 PM.png  predicted class is  rottenbanana  with probability  0.98746777
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.57.34 PM.png  predicted class is  rottenbanana  with probability  0.999879
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.58.18 PM.png  predicted class is  rottenbanana  with probability  0.99997675
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.01.32 PM.png  predicted class is  rottenbanana  with probability  0.9991811
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.01.35 PM.png  predicted class is  rottenbanana  with probability  0.99994016
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.01.56 PM.png  predicted class is  rottenbanana  with probability  0.9999957
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.02.09 PM.png  predicted class is  rottenbanana  with probability  0.99999845
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.02.44 PM.png  predicted class is  rottenbanana  with probability  0.99999857
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.03.30 PM.png  predicted class is  rottenbanana  with probability  0.9999987
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.03.34 PM.png  predicted class is  rottenbanana  with probability  0.99999964
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.04.01 PM.png  predicted class is  rottenbanana  with probability  0.9999982
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.05.21 PM.png  predicted class is  rottenbanana  with probability  0.8747316
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.06.33 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.07.46 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.08.00 PM.png  predicted class is  rottenbanana  with probability  0.9999958
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.10.37 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.11.23 PM.png  predicted class is  rottenbanana  with probability  0.99954385
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.12.27 PM.png  predicted class is  rottenbanana  with probability  0.99995494
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.12.45 PM.png  predicted class is  rottenbanana  with probability  0.9999994
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.13.16 PM.png  predicted class is  rottenbanana  with probability  0.9843424
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.13.21 PM.png  predicted class is  rottenbanana  with probability  0.9997489
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.13.34 PM.png  predicted class is  rottenbanana  with probability  0.99999917
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.14.43 PM.png  predicted class is  rottenbanana  with probability  0.9999988
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.16.57 PM.png  predicted class is  rottenbanana  with probability  0.99999595
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.17.19 PM.png  predicted class is  rottenbanana  with probability  0.9999951
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.17.57 PM.png  predicted class is  rottenbanana  with probability  0.9998561
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.19.35 PM.png  predicted class is  rottenbanana  with probability  0.9999994
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.20.01 PM.png  predicted class is  rottenbanana  with probability  0.99999964
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.20.47 PM.png  predicted class is  rottenbanana  with probability  0.9999932
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.23.15 PM.png  predicted class is  rottenbanana  with probability  0.9999455
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.00 PM.png  predicted class is  rottenbanana  with probability  0.9999993
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.04 PM.png  predicted class is  rottenbanana  with probability  0.99990034
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.34 PM.png  predicted class is  rottenbanana  with probability  0.9999994
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.41 PM.png  predicted class is  rottenbanana  with probability  0.9999907
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.54 PM.png  predicted class is  rottenbanana  with probability  0.99999726
# for file  rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.27.56 PM.png  predicted class is  rottenbanana  with probability  0.99999905
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.47.41 PM.png  predicted class is  rottenbanana  with probability  0.99994886
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.49.41 PM.png  predicted class is  rottenbanana  with probability  0.99587053
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.50.04 PM.png  predicted class is  rottenbanana  with probability  0.99993765
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.50.47 PM.png  predicted class is  rottenbanana  with probability  0.9999807
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.50.54 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.51.30 PM.png  predicted class is  rottenbanana  with probability  0.9999865
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.51.46 PM.png  predicted class is  rottenbanana  with probability  0.9999993
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.51.56 PM.png  predicted class is  rottenbanana  with probability  0.99991894
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.52.01 PM.png  predicted class is  rottenbanana  with probability  0.9999305
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.52.11 PM.png  predicted class is  rottenbanana  with probability  0.9999987
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.53.42 PM.png  predicted class is  rottenbanana  with probability  0.99993575
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.53.54 PM.png  predicted class is  rottenbanana  with probability  0.99940395
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.55.08 PM.png  predicted class is  rottenbanana  with probability  0.9999752
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.55.35 PM.png  predicted class is  rottenbanana  with probability  0.9999931
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.56.01 PM.png  predicted class is  rottenbanana  with probability  0.99993455
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.56.30 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.57.46 PM.png  predicted class is  rottenbanana  with probability  0.99718577
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.58.07 PM.png  predicted class is  rottenbanana  with probability  0.99911803
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.58.57 PM.png  predicted class is  rottenbanana  with probability  0.9990889
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.59.32 PM.png  predicted class is  rottenbanana  with probability  0.9999763
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.00.11 PM.png  predicted class is  rottenbanana  with probability  0.9999999
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.00.17 PM.png  predicted class is  rottenbanana  with probability  0.99996626
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.01.10 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.01.21 PM.png  predicted class is  rottenbanana  with probability  0.999923
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.01.26 PM.png  predicted class is  rottenbanana  with probability  0.99999547
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.01.56 PM.png  predicted class is  rottenbanana  with probability  0.9999552
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.02.03 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.03.25 PM.png  predicted class is  rottenbanana  with probability  0.99961334
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.03.40 PM.png  predicted class is  rottenbanana  with probability  0.9999852
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.04.01 PM.png  predicted class is  rottenbanana  with probability  0.99999917
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.04.08 PM.png  predicted class is  rottenbanana  with probability  0.99997747
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.04.19 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.05.08 PM.png  predicted class is  rottenbanana  with probability  0.99999857
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.05.37 PM.png  predicted class is  rottenbanana  with probability  0.99992704
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.06.33 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.07.26 PM.png  predicted class is  rottenbanana  with probability  0.9999995
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.09.16 PM.png  predicted class is  rottenbanana  with probability  0.99998474
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.09.43 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.10.10 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.10.45 PM.png  predicted class is  rottenbanana  with probability  0.99982494
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.11.05 PM.png  predicted class is  rottenbanana  with probability  0.9999927
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.11.35 PM.png  predicted class is  rottenbanana  with probability  0.9213194
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.11.43 PM.png  predicted class is  rottenbanana  with probability  0.99985576
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.11.52 PM.png  predicted class is  rottenbanana  with probability  1.0
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.12.11 PM.png  predicted class is  rottenbanana  with probability  0.9999856
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.12.32 PM.png  predicted class is  rottenbanana  with probability  0.9995784
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.12.57 PM.png  predicted class is  rottenbanana  with probability  0.99999845
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.13.21 PM.png  predicted class is  rottenbanana  with probability  0.99952793
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.13.39 PM.png  predicted class is  rottenbanana  with probability  0.99999225
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.13.54 PM.png  predicted class is  rottenbanana  with probability  0.9705796
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.14.22 PM.png  predicted class is  rottenbanana  with probability  0.9976018
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.14.48 PM.png  predicted class is  rottenbanana  with probability  0.9975794
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.16.28 PM.png  predicted class is  rottenbanana  with probability  0.9999951
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.17.44 PM.png  predicted class is  rottenbanana  with probability  0.9998479
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.18.11 PM.png  predicted class is  rottenbanana  with probability  0.99993765
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.19.03 PM.png  predicted class is  rottenbanana  with probability  0.9999987
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.20.01 PM.png  predicted class is  rottenbanana  with probability  0.99999964
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.22.13 PM.png  predicted class is  rottenbanana  with probability  0.9976901
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.22.57 PM.png  predicted class is  rottenbanana  with probability  0.99999595
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.23.15 PM.png  predicted class is  rottenbanana  with probability  0.99999356
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.25.23 PM.png  predicted class is  rottenbanana  with probability  0.999954
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.25.28 PM.png  predicted class is  rottenbanana  with probability  0.7779803
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.25.41 PM.png  predicted class is  rottenbanana  with probability  0.9999856
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.26.27 PM.png  predicted class is  rottenbanana  with probability  0.9999937
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.27.15 PM.png  predicted class is  rottenbanana  with probability  0.999997
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.27.35 PM.png  predicted class is  rottenbanana  with probability  0.9999341
# for file  rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.27.46 PM.png  predicted class is  rottenbanana  with probability  0.9999666
# ...
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.09.03 PM.png  predicted class is  freshapples  with probability  0.99998784
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.09.40 PM.png  predicted class is  freshapples  with probability  0.9996933
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.10.11 PM.png  predicted class is  freshapples  with probability  0.99999464
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.11.35 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.11.59 PM.png  predicted class is  freshapples  with probability  0.9949581
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.12.14 PM.png  predicted class is  freshapples  with probability  0.9999093
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.12.41 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.12.47 PM.png  predicted class is  freshapples  with probability  0.9999963
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.13.45 PM.png  predicted class is  freshapples  with probability  0.99999404
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.14.56 PM.png  predicted class is  freshapples  with probability  0.99996495
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.15.14 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.15.21 PM.png  predicted class is  freshapples  with probability  0.9996449
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.15.52 PM.png  predicted class is  freshapples  with probability  0.99995565
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.16.06 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.16.28 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.16.57 PM.png  predicted class is  freshapples  with probability  0.9999995
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.18.37 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.18.51 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.21.35 PM.png  predicted class is  freshapples  with probability  0.9999925
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.22.48 PM.png  predicted class is  freshapples  with probability  0.98936325
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.23.31 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.24.12 PM.png  predicted class is  freshapples  with probability  0.9999585
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.24.19 PM.png  predicted class is  freshapples  with probability  0.99999917
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.25.28 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.25.49 PM.png  predicted class is  freshapples  with probability  0.97228426
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.26.29 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.28.10 PM.png  predicted class is  freshapples  with probability  0.94743764
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.28.59 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.29.13 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.29.31 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.34.01 PM.png  predicted class is  freshapples  with probability  0.9999901
# for file  freshapples/saltandpepper_Screen Shot 2018-06-08 at 5.34.14 PM.png  predicted class is  freshapples  with probability  0.9867269
# for file  freshapples/translation_Screen Shot 2018-06-08 at 4.59.36 PM.png  predicted class is  freshapples  with probability  0.999998
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.00.18 PM.png  predicted class is  freshapples  with probability  0.9999999
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.01.15 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.02.43 PM.png  predicted class is  freshapples  with probability  0.9999201
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.03.10 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.03.17 PM.png  predicted class is  freshapples  with probability  0.9999999
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.07.05 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.07.32 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.08.37 PM.png  predicted class is  freshapples  with probability  0.9999745
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.09.47 PM.png  predicted class is  freshapples  with probability  0.99997735
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.10.53 PM.png  predicted class is  freshapples  with probability  0.9998821
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.11.08 PM.png  predicted class is  freshapples  with probability  0.99997807
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.13.25 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.14.07 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.14.20 PM.png  predicted class is  freshapples  with probability  0.9999988
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.14.56 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.15.01 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.15.39 PM.png  predicted class is  freshapples  with probability  0.9999472
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.16.33 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.16.37 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.16.57 PM.png  predicted class is  freshapples  with probability  0.9999993
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.17.04 PM.png  predicted class is  freshapples  with probability  0.99896896
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.18.37 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.18.51 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.19.28 PM.png  predicted class is  freshapples  with probability  0.9999776
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.20.51 PM.png  predicted class is  rottenapples  with probability  0.7085226
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.21.51 PM.png  predicted class is  freshapples  with probability  0.99999607
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.21.56 PM.png  predicted class is  freshapples  with probability  0.9950773
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.23.26 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.24.04 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.24.19 PM.png  predicted class is  freshapples  with probability  0.99999523
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.25.28 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.25.54 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.26.52 PM.png  predicted class is  freshapples  with probability  0.9487949
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.29.07 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.32.50 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/translation_Screen Shot 2018-06-08 at 5.33.05 PM.png  predicted class is  freshapples  with probability  0.990386
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 4.59.49 PM.png  predicted class is  freshapples  with probability  0.99974936
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.00.35 PM.png  predicted class is  freshapples  with probability  0.99999654
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.00.43 PM.png  predicted class is  freshapples  with probability  0.99999917
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.01.01 PM.png  predicted class is  freshapples  with probability  0.99999595
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.01.08 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.03.59 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.04.24 PM.png  predicted class is  freshapples  with probability  0.98204917
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.04.42 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.04.48 PM.png  predicted class is  freshapples  with probability  0.88859326
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.04.59 PM.png  predicted class is  freshapples  with probability  0.9526697
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.05.12 PM.png  predicted class is  freshapples  with probability  0.5924235
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.06.10 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.06.40 PM.png  predicted class is  freshapples  with probability  0.9995427
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.06.47 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.07.05 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.08.46 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.08.52 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.09.47 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.10.53 PM.png  predicted class is  freshapples  with probability  0.9999989
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.11.02 PM.png  predicted class is  freshapples  with probability  0.9999825
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.12.56 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.13.02 PM.png  predicted class is  freshapples  with probability  0.927242
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.13.31 PM.png  predicted class is  freshapples  with probability  0.93705946
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.14.56 PM.png  predicted class is  freshapples  with probability  0.9999248
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.15.21 PM.png  predicted class is  freshapples  with probability  0.9999002
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.15.28 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.16.28 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.18.26 PM.png  predicted class is  freshapples  with probability  0.999998
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.18.37 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.20.56 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.21.31 PM.png  predicted class is  freshapples  with probability  0.73140436
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.21.51 PM.png  predicted class is  rottenapples  with probability  0.97336435
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.23.14 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.24.04 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.26.13 PM.png  predicted class is  freshapples  with probability  0.9970499
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.26.29 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.26.36 PM.png  predicted class is  freshapples  with probability  0.99997926
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.26.58 PM.png  predicted class is  freshoranges  with probability  0.35930744
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.28.10 PM.png  predicted class is  freshapples  with probability  0.9525963
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.28.42 PM.png  predicted class is  freshapples  with probability  0.97986364
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.28.48 PM.png  predicted class is  freshapples  with probability  0.957397
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.29.13 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.29.18 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.32.38 PM.png  predicted class is  freshapples  with probability  0.87723213
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.32.43 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.32.50 PM.png  predicted class is  freshapples  with probability  1.0
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.33.05 PM.png  predicted class is  freshapples  with probability  0.99999785
# for file  freshapples/vertical_flip_Screen Shot 2018-06-08 at 5.33.27 PM.png  predicted class is  freshapples  with probability  0.99999964

# %%
print(len(test_generator[0][0]))
print(test_generator[0][1].shape)
# Out:
# 1
# (1, 6)

# %%
fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(12, 10))
idx = 0

for i in range(3):
    for j in range(4):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[idx][0].reshape(240,240,3))
        ax[i, j].axis("off")
        idx += 200

# plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
from keras.utils.vis_utils import plot_model
tf.keras.utils.plot_model(
model, to_file='model.png', show_shapes=True, show_dtype=False,
show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96
)

# %%
model.save('Modelv1.h5')
